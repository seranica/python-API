# %% [markdown]
# ### WeatherPy

# %%
'''
The API portion of this solution is based on Juan Luong's published instuctor demo 
'Ins_OpenWeatherDataFrame.ipynb' (6.2 Activity 5)
'''

# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
import numpy as np
from citipy import citipy
from scipy.stats import linregress
from matplotlib import pyplot as plt

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %% [markdown]
# ## Generate Cities List

# %%
#create lists for saving coordinates
lat_lngs = []
city_list = []

# Create random list of coordinates. Needs 3 decimal places, must be used as float.
lats = np.random.uniform(low=-90.000, high=90.000, size = 1300)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 1300)

# Identify nearest city using citipy library for random lat, lngs pair
for i in range(len(lats)):
    city = citipy.nearest_city(lats[i], lngs[i]).city_name
    if city not in city_list:
        city_list.append(city)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
lat = []
lng=[]
temp = []
humidity = []
cloudiness = []
wind =[]
cities = []

#Country required for later (VacationPy)
country=[]

# Loop through the list of cities and perform a request for data on each
for city in city_list:
    #Using try - except block to move past cities without OpenWeather data
    try:
        print(city)
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        cities.append(city)
        #Use length of lat list to track additions
        print(f"City number {len(lat)} is {city}.")
    except:
        continue
        print(f"City ({city}) not returning OpenWeather data. Try next city...")
# Out:
# khasan
# City no.1 is khasan.
# tuktoyaktuk
# City no.2 is tuktoyaktuk.
# vaini
# City no.3 is vaini.
# palabuhanratu
# mataura
# City no.4 is mataura.
# taolanaro
# lata
# City no.5 is lata.
# jamestown
# City no.6 is jamestown.
# busselton
# City no.7 is busselton.
# bluff
# City no.8 is bluff.
# san andres
# City no.9 is san andres.
# sahrak
# punta arenas
# City no.10 is punta arenas.
# qaanaaq
# City no.11 is qaanaaq.
# hithadhoo
# City no.12 is hithadhoo.
# arraial do cabo
# City no.13 is arraial do cabo.
# east london
# City no.14 is east london.
# beloha
# City no.15 is beloha.
# samusu
# krasnogorskoye
# City no.16 is krasnogorskoye.
# butaritari
# City no.17 is butaritari.
# hilo
# City no.18 is hilo.
# souillac
# City no.19 is souillac.
# sault sainte marie
# City no.20 is sault sainte marie.
# solwezi
# City no.21 is solwezi.
# castro
# City no.22 is castro.
# lagoa
# City no.23 is lagoa.
# barentsburg
# kavieng
# City no.24 is kavieng.
# ushuaia
# City no.25 is ushuaia.
# ascension
# City no.26 is ascension.
# laguna
# City no.27 is laguna.
# rikitea
# City no.28 is rikitea.
# sampit
# City no.29 is sampit.
# tessalit
# City no.30 is tessalit.
# albany
# City no.31 is albany.
# barra do corda
# City no.32 is barra do corda.
# touros
# City no.33 is touros.
# poddorye
# City no.34 is poddorye.
# lebu
# City no.35 is lebu.
# bethel
# City no.36 is bethel.
# ribeira grande
# City no.37 is ribeira grande.
# kapaa
# City no.38 is kapaa.
# narsaq
# City no.39 is narsaq.
# port hawkesbury
# City no.40 is port hawkesbury.
# georgetown
# City no.41 is georgetown.
# belushya guba
# sandwick
# City no.42 is sandwick.
# terrace bay
# City no.43 is terrace bay.
# hermanus
# City no.44 is hermanus.
# victoria
# City no.45 is victoria.
# atuona
# City no.46 is atuona.
# kaitangata
# City no.47 is kaitangata.
# mar del plata
# City no.48 is mar del plata.
# tura
# City no.49 is tura.
# dalby
# City no.50 is dalby.
# labutta
# itarema
# City no.51 is itarema.
# bambous virieux
# City no.52 is bambous virieux.
# cheuskiny
# fontem
# City no.53 is fontem.
# tukrah
# City no.54 is tukrah.
# provideniya
# City no.55 is provideniya.
# carballo
# City no.56 is carballo.
# ust-kamchatsk
# saldanha
# City no.57 is saldanha.
# addi ugri
# canto do buriti
# City no.58 is canto do buriti.
# pevek
# City no.59 is pevek.
# bengkulu
# City no.60 is bengkulu.
# attawapiskat
# egvekinot
# City no.61 is egvekinot.
# pontianak
# City no.62 is pontianak.
# keuruu
# City no.63 is keuruu.
# rocha
# City no.64 is rocha.
# hasaki
# City no.65 is hasaki.
# port elizabeth
# City no.66 is port elizabeth.
# altamira
# City no.67 is altamira.
# gumushane
# churapcha
# City no.68 is churapcha.
# umzimvubu
# lompoc
# City no.69 is lompoc.
# beringovskiy
# City no.70 is beringovskiy.
# ust-maya
# City no.71 is ust-maya.
# malwan
# avarua
# City no.72 is avarua.
# bredasdorp
# City no.73 is bredasdorp.
# puerto ayora
# City no.74 is puerto ayora.
# arman
# City no.75 is arman.
# severo-kurilsk
# City no.76 is severo-kurilsk.
# klaksvik
# City no.77 is klaksvik.
# tasiilaq
# City no.78 is tasiilaq.
# kerema
# City no.79 is kerema.
# san quintin
# City no.80 is san quintin.
# voi
# City no.81 is voi.
# kristiansund
# City no.82 is kristiansund.
# hobart
# City no.83 is hobart.
# naze
# City no.84 is naze.
# westport
# City no.85 is westport.
# thompson
# City no.86 is thompson.
# broome
# City no.87 is broome.
# dubi
# City no.88 is dubi.
# batemans bay
# City no.89 is batemans bay.
# urucara
# City no.90 is urucara.
# srandakan
# City no.91 is srandakan.
# mataram
# City no.92 is mataram.
# nishihara
# City no.93 is nishihara.
# vila
# City no.94 is vila.
# dhidhdhoo
# City no.95 is dhidhdhoo.
# ilulissat
# City no.96 is ilulissat.
# yellowknife
# City no.97 is yellowknife.
# tabuk
# City no.98 is tabuk.
# carnarvon
# City no.99 is carnarvon.
# banamba
# City no.100 is banamba.
# nushki
# City no.101 is nushki.
# miraflores
# City no.102 is miraflores.
# rudnogorsk
# City no.103 is rudnogorsk.
# lorengau
# City no.104 is lorengau.
# cayenne
# City no.105 is cayenne.
# kaeo
# City no.106 is kaeo.
# pangnirtung
# City no.107 is pangnirtung.
# kajaani
# City no.108 is kajaani.
# saint-philippe
# City no.109 is saint-philippe.
# temaraia
# tiksi
# City no.110 is tiksi.
# novoderevyankovskaya
# City no.111 is novoderevyankovskaya.
# dikson
# City no.112 is dikson.
# sabang
# City no.113 is sabang.
# hereford
# City no.114 is hereford.
# quesnel
# City no.115 is quesnel.
# namatanai
# City no.116 is namatanai.
# nikolskoye
# City no.117 is nikolskoye.
# luyang
# City no.118 is luyang.
# tumannyy
# sola
# City no.119 is sola.
# mana
# City no.120 is mana.
# rungata
# darnah
# City no.121 is darnah.
# barrow
# City no.122 is barrow.
# cervo
# City no.123 is cervo.
# spornoye
# City no.124 is spornoye.
# lovozero
# City no.125 is lovozero.
# santa maria
# City no.126 is santa maria.
# fort nelson
# City no.127 is fort nelson.
# san patricio
# City no.128 is san patricio.
# khonuu
# jiayuguan
# City no.129 is jiayuguan.
# barbar
# davidson
# City no.130 is davidson.
# barranca
# City no.131 is barranca.
# esperance
# City no.132 is esperance.
# eyl
# City no.133 is eyl.
# atikokan
# City no.134 is atikokan.
# sandpoint
# City no.135 is sandpoint.
# shawville
# City no.136 is shawville.
# makakilo city
# City no.137 is makakilo city.
# sentyabrskiy
# grand river south east
# donskoye
# City no.138 is donskoye.
# upernavik
# City no.139 is upernavik.
# hamilton
# City no.140 is hamilton.
# korla
# City no.141 is korla.
# mehamn
# City no.142 is mehamn.
# bud
# City no.143 is bud.
# sao felix do xingu
# City no.144 is sao felix do xingu.
# kruisfontein
# City no.145 is kruisfontein.
# airai
# City no.146 is airai.
# asau
# City no.147 is asau.
# cherskiy
# City no.148 is cherskiy.
# morro bay
# City no.149 is morro bay.
# toliary
# ola
# City no.150 is ola.
# bukachacha
# City no.151 is bukachacha.
# shaowu
# City no.152 is shaowu.
# rawson
# City no.153 is rawson.
# wynyard
# City no.154 is wynyard.
# gijon
# City no.155 is gijon.
# tezu
# City no.156 is tezu.
# lieksa
# City no.157 is lieksa.
# great yarmouth
# City no.158 is great yarmouth.
# kulhudhuffushi
# City no.159 is kulhudhuffushi.
# fairbanks
# City no.160 is fairbanks.
# morehead
# City no.161 is morehead.
# sorland
# City no.162 is sorland.
# ancud
# City no.163 is ancud.
# iqaluit
# City no.164 is iqaluit.
# wilmington
# City no.165 is wilmington.
# jiddah
# barcelona
# City no.166 is barcelona.
# mahebourg
# City no.167 is mahebourg.
# torbay
# City no.168 is torbay.
# daru
# City no.169 is daru.
# port alfred
# City no.170 is port alfred.
# margate
# City no.171 is margate.
# kysyl-syr
# City no.172 is kysyl-syr.
# paso de los toros
# City no.173 is paso de los toros.
# rio gallegos
# City no.174 is rio gallegos.
# adamus
# City no.175 is adamus.
# north platte
# City no.176 is north platte.
# weatherford
# City no.177 is weatherford.
# marawi
# City no.178 is marawi.
# talnakh
# City no.179 is talnakh.
# geraldton
# City no.180 is geraldton.
# kodiak
# City no.181 is kodiak.
# ballina
# City no.182 is ballina.
# bonthe
# City no.183 is bonthe.
# seddon
# City no.184 is seddon.
# garoua
# City no.185 is garoua.
# evensk
# City no.186 is evensk.
# ahipara
# City no.187 is ahipara.
# kalaleh
# City no.188 is kalaleh.
# te anau
# City no.189 is te anau.
# clyde river
# City no.190 is clyde river.
# zhigansk
# City no.191 is zhigansk.
# mount isa
# City no.192 is mount isa.
# manutuke
# City no.193 is manutuke.
# cape town
# City no.194 is cape town.
# leningradskiy
# City no.195 is leningradskiy.
# khatanga
# City no.196 is khatanga.
# saint-augustin
# City no.197 is saint-augustin.
# antsohihy
# City no.198 is antsohihy.
# bajo baudo
# mys shmidta
# general roca
# City no.199 is general roca.
# kokopo
# City no.200 is kokopo.
# luangwa
# City no.201 is luangwa.
# villarrica
# City no.202 is villarrica.
# maribo
# City no.203 is maribo.
# nicolas bravo
# City no.204 is nicolas bravo.
# shenjiamen
# City no.205 is shenjiamen.
# marzuq
# City no.206 is marzuq.
# los llanos de aridane
# City no.207 is los llanos de aridane.
# kindu
# City no.208 is kindu.
# namibe
# City no.209 is namibe.
# camana
# City no.210 is camana.
# bosaso
# City no.211 is bosaso.
# yulara
# City no.212 is yulara.
# micheweni
# City no.213 is micheweni.
# new norfolk
# City no.214 is new norfolk.
# stornoway
# City no.215 is stornoway.
# ponta do sol
# City no.216 is ponta do sol.
# iquique
# City no.217 is iquique.
# kavaratti
# City no.218 is kavaratti.
# aswan
# City no.219 is aswan.
# hambantota
# City no.220 is hambantota.
# gat
# City no.221 is gat.
# son la
# City no.222 is son la.
# cabo san lucas
# City no.223 is cabo san lucas.
# vaitupu
# atocha
# City no.224 is atocha.
# zachary
# City no.225 is zachary.
# taunggyi
# City no.226 is taunggyi.
# chokurdakh
# City no.227 is chokurdakh.
# raudeberg
# City no.228 is raudeberg.
# nago
# City no.229 is nago.
# turukhansk
# City no.230 is turukhansk.
# rundu
# City no.231 is rundu.
# acapulco
# City no.232 is acapulco.
# padang
# City no.233 is padang.
# scarborough
# City no.234 is scarborough.
# baragaon
# City no.235 is baragaon.
# omsukchan
# City no.236 is omsukchan.
# gigmoto
# City no.237 is gigmoto.
# tymovskoye
# City no.238 is tymovskoye.
# hami
# City no.239 is hami.
# muli
# City no.240 is muli.
# roald
# City no.241 is roald.
# jieshi
# City no.242 is jieshi.
# soyo
# City no.243 is soyo.
# dali
# City no.244 is dali.
# kuryk
# City no.245 is kuryk.
# celldomolk
# City no.246 is celldomolk.
# tuatapere
# City no.247 is tuatapere.
# antrim
# City no.248 is antrim.
# faanui
# City no.249 is faanui.
# ugoofaaru
# City no.250 is ugoofaaru.
# vila do maio
# City no.251 is vila do maio.
# rosehearty
# City no.252 is rosehearty.
# chuy
# City no.253 is chuy.
# richmond hill
# City no.254 is richmond hill.
# alofi
# City no.255 is alofi.
# heihe
# City no.256 is heihe.
# barra patuca
# City no.257 is barra patuca.
# berdigestyakh
# City no.258 is berdigestyakh.
# jujuy
# havoysund
# City no.259 is havoysund.
# mayo
# City no.260 is mayo.
# caxito
# City no.261 is caxito.
# antonina
# City no.262 is antonina.
# carros
# City no.263 is carros.
# zakamensk
# City no.264 is zakamensk.
# tigil
# City no.265 is tigil.
# lolua
# illoqqortoormiut
# okhotsk
# City no.266 is okhotsk.
# mount gambier
# City no.267 is mount gambier.
# firminy
# City no.268 is firminy.
# ixtapa
# City no.269 is ixtapa.
# lasa
# City no.270 is lasa.
# kaoma
# City no.271 is kaoma.
# fukue
# City no.272 is fukue.
# buchanan
# City no.273 is buchanan.
# oranjemund
# City no.274 is oranjemund.
# qui nhon
# City no.275 is qui nhon.
# cukai
# City no.276 is cukai.
# bussigny
# City no.277 is bussigny.
# savannah bight
# City no.278 is savannah bight.
# xingyi
# City no.279 is xingyi.
# chalchihuites
# City no.280 is chalchihuites.
# port macquarie
# City no.281 is port macquarie.
# utiroa
# riyadh
# City no.282 is riyadh.
# tsihombe
# ballangen
# City no.283 is ballangen.
# tulum
# City no.284 is tulum.
# arrecife
# City no.285 is arrecife.
# hondo
# City no.286 is hondo.
# oranjestad
# City no.287 is oranjestad.
# manacapuru
# City no.288 is manacapuru.
# vestmanna
# City no.289 is vestmanna.
# bandiagara
# City no.290 is bandiagara.
# xinzhou
# City no.291 is xinzhou.
# poum
# City no.292 is poum.
# portland
# City no.293 is portland.
# jibuti
# City no.294 is jibuti.
# ivolginsk
# City no.295 is ivolginsk.
# atar
# City no.296 is atar.
# pedro ii
# City no.297 is pedro ii.
# nalut
# City no.298 is nalut.
# bani walid
# City no.299 is bani walid.
# antalaha
# City no.300 is antalaha.
# okato
# City no.301 is okato.
# krasnoselkup
# City no.302 is krasnoselkup.
# saskylakh
# City no.303 is saskylakh.
# bargal
# kargopol
# City no.304 is kargopol.
# manicore
# City no.305 is manicore.
# aklavik
# City no.306 is aklavik.
# denpasar
# City no.307 is denpasar.
# batagay
# City no.308 is batagay.
# sao jose da coroa grande
# City no.309 is sao jose da coroa grande.
# bereda
# City no.310 is bereda.
# odweyne
# City no.311 is odweyne.
# sjovegan
# City no.312 is sjovegan.
# resende
# City no.313 is resende.
# nemyriv
# City no.314 is nemyriv.
# santa marta
# City no.315 is santa marta.
# semirom
# City no.316 is semirom.
# novikovo
# City no.317 is novikovo.
# praia da vitoria
# City no.318 is praia da vitoria.
# guerrero negro
# City no.319 is guerrero negro.
# sinop
# City no.320 is sinop.
# katsuura
# City no.321 is katsuura.
# dukat
# City no.322 is dukat.
# srednekolymsk
# City no.323 is srednekolymsk.
# inuvik
# City no.324 is inuvik.
# nanortalik
# City no.325 is nanortalik.
# berlevag
# City no.326 is berlevag.
# khor
# City no.327 is khor.
# novodolinskiy
# City no.328 is novodolinskiy.
# muisne
# City no.329 is muisne.
# sao joao da barra
# City no.330 is sao joao da barra.
# port-cartier
# City no.331 is port-cartier.
# taft
# City no.332 is taft.
# longyearbyen
# City no.333 is longyearbyen.
# praia
# City no.334 is praia.
# bilibino
# City no.335 is bilibino.
# boo
# City no.336 is boo.
# hualmay
# City no.337 is hualmay.
# belyy yar
# City no.338 is belyy yar.
# baruun-urt
# City no.339 is baruun-urt.
# sorvag
# monkey bay
# City no.340 is monkey bay.
# juneau
# City no.341 is juneau.
# yar-sale
# City no.342 is yar-sale.
# itaituba
# City no.343 is itaituba.
# sabha
# City no.344 is sabha.
# porto novo
# City no.345 is porto novo.
# luderitz
# City no.346 is luderitz.
# itabira
# City no.347 is itabira.
# varnamo
# City no.348 is varnamo.
# anchorage
# City no.349 is anchorage.
# flinders
# City no.350 is flinders.
# sompeta
# City no.351 is sompeta.
# tarudant
# pudozh
# City no.352 is pudozh.
# hay river
# City no.353 is hay river.
# muhos
# City no.354 is muhos.
# starkville
# City no.355 is starkville.
# hokitika
# City no.356 is hokitika.
# sturgis
# City no.357 is sturgis.
# pennsauken
# City no.358 is pennsauken.
# kamenskoye
# khorixas
# City no.359 is khorixas.
# shingu
# City no.360 is shingu.
# gwanda
# City no.361 is gwanda.
# vanimo
# City no.362 is vanimo.
# jaten
# City no.363 is jaten.
# pointe michel
# City no.364 is pointe michel.
# nizhneyansk
# roros
# City no.365 is roros.
# kankaanpaa
# City no.366 is kankaanpaa.
# brufut
# City no.367 is brufut.
# ariquemes
# City no.368 is ariquemes.
# beira
# City no.369 is beira.
# nanchang
# City no.370 is nanchang.
# torres
# City no.371 is torres.
# pacific grove
# City no.372 is pacific grove.
# rionero in vulture
# City no.373 is rionero in vulture.
# monrovia
# City no.374 is monrovia.
# rorvik
# City no.375 is rorvik.
# yunyang
# City no.376 is yunyang.
# sovetsk
# City no.377 is sovetsk.
# hovd
# City no.378 is hovd.
# kuche
# amderma
# aykhal
# City no.379 is aykhal.
# chicama
# City no.380 is chicama.
# harper
# City no.381 is harper.
# neya
# City no.382 is neya.
# burns lake
# City no.383 is burns lake.
# saint george
# City no.384 is saint george.
# tanga
# City no.385 is tanga.
# ouargaye
# City no.386 is ouargaye.
# bombay
# City no.387 is bombay.
# turkistan
# City no.388 is turkistan.
# ucluelet
# City no.389 is ucluelet.
# kralendijk
# City no.390 is kralendijk.
# nokha
# City no.391 is nokha.
# ozgon
# hebi
# City no.392 is hebi.
# quatre cocos
# City no.393 is quatre cocos.
# itacarambi
# City no.394 is itacarambi.
# mitsamiouli
# City no.395 is mitsamiouli.
# cidreira
# City no.396 is cidreira.
# kirovskaya
# City no.397 is kirovskaya.
# portales
# City no.398 is portales.
# cockburn town
# City no.399 is cockburn town.
# narasannapeta
# City no.400 is narasannapeta.
# college
# City no.401 is college.
# arona
# City no.402 is arona.
# port blair
# City no.403 is port blair.
# dinsor
# virginia beach
# City no.404 is virginia beach.
# qandala
# City no.405 is qandala.
# kamisu
# City no.406 is kamisu.
# mahajanga
# City no.407 is mahajanga.
# blonduos
# monterrey
# City no.408 is monterrey.
# saint peters
# City no.409 is saint peters.
# lerwick
# City no.410 is lerwick.
# artyk
# warqla
# simao
# City no.411 is simao.
# richards bay
# City no.412 is richards bay.
# kamloops
# City no.413 is kamloops.
# fethiye
# City no.414 is fethiye.
# lusambo
# City no.415 is lusambo.
# champerico
# City no.416 is champerico.
# san blas
# City no.417 is san blas.
# ust-tsilma
# City no.418 is ust-tsilma.
# balkanabat
# City no.419 is balkanabat.
# zeya
# City no.420 is zeya.
# husavik
# City no.421 is husavik.
# maraa
# City no.422 is maraa.
# ponta delgada
# City no.423 is ponta delgada.
# urengoy
# City no.424 is urengoy.
# rogovatoye
# City no.425 is rogovatoye.
# wagga wagga
# City no.426 is wagga wagga.
# satitoa
# havre
# City no.427 is havre.
# kabala
# City no.428 is kabala.
# kargil
# City no.429 is kargil.
# tyssedal
# City no.430 is tyssedal.
# halalo
# sioux lookout
# City no.431 is sioux lookout.
# nabire
# City no.432 is nabire.
# vostochnyy
# City no.433 is vostochnyy.
# neijiang
# City no.434 is neijiang.
# hofn
# City no.435 is hofn.
# inta
# City no.436 is inta.
# koumac
# City no.437 is koumac.
# brive-la-gaillarde
# City no.438 is brive-la-gaillarde.
# buin
# City no.439 is buin.
# burgos
# City no.440 is burgos.
# zhongxing
# City no.441 is zhongxing.
# doha
# City no.442 is doha.
# bathsheba
# City no.443 is bathsheba.
# union city
# City no.444 is union city.
# ormara
# City no.445 is ormara.
# shubarshi
# City no.446 is shubarshi.
# karasburg
# City no.447 is karasburg.
# mashivka
# City no.448 is mashivka.
# irbil
# City no.449 is irbil.
# chunskiy
# City no.450 is chunskiy.
# nyurba
# City no.451 is nyurba.
# mpanda
# City no.452 is mpanda.
# ayacucho
# City no.453 is ayacucho.
# chaa-khol
# shahreza
# City no.454 is shahreza.
# kiunga
# City no.455 is kiunga.
# tiznit
# City no.456 is tiznit.
# maniitsoq
# City no.457 is maniitsoq.
# chincha alta
# City no.458 is chincha alta.
# oxbow
# City no.459 is oxbow.
# grand gaube
# City no.460 is grand gaube.
# cumaribo
# acarau
# City no.461 is acarau.
# vardo
# City no.462 is vardo.
# sao filipe
# City no.463 is sao filipe.
# anadyr
# City no.464 is anadyr.
# grindavik
# City no.465 is grindavik.
# acari
# City no.466 is acari.
# pemangkat
# City no.467 is pemangkat.
# varberg
# City no.468 is varberg.
# sorong
# City no.469 is sorong.
# maloshuyka
# kochubey
# City no.470 is kochubey.
# progreso
# City no.471 is progreso.
# katherine
# City no.472 is katherine.
# imbituba
# City no.473 is imbituba.
# marica
# City no.474 is marica.
# coquimbo
# City no.475 is coquimbo.
# sobolivka
# City no.476 is sobolivka.
# coolum beach
# City no.477 is coolum beach.
# miandrivazo
# City no.478 is miandrivazo.
# saint anthony
# City no.479 is saint anthony.
# norman wells
# City no.480 is norman wells.
# tazovskiy
# City no.481 is tazovskiy.
# vryburg
# City no.482 is vryburg.
# northam
# City no.483 is northam.

# %%
#Check query has returned at least 500 cities
print(len(cities))
# Out:
# 483

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Save lists to dataframe
weather_dict = {
    "City": cities,
    "Country": country,
    "Lat": lat,
    "Lng": lng,
    "Temp": temp,
    "Humidity":humidity,
    "Wind Speed": wind,
    "Cloudiness": cloudiness
}

#Create a copy 
weather_data = pd.DataFrame(weather_dict)

#Save dataframe to *.csv
weather_data.to_csv("weatherpy.csv")

#Check *.csv by importing and printing
filepath= "weatherpy.csv"
weather_df = pd.read_csv(filepath)
weather_df.head()
# Out:
#    Unnamed: 0         City Country    Lat     Lng   Temp  Humidity  \
# 0           0       khasan      RU  42.43  130.64  57.02        43
# 1           1  tuktoyaktuk      CA  69.45 -133.04  14.00        85
# 2           2        vaini      TO -21.20 -175.20  73.40        88
# 3           3      mataura      NZ -46.19  168.86  55.99        57
# 4           4         lata      PT  40.16   -8.33  49.28        91
#
#    Wind Speed  Cloudiness
# 0        0.49           0
# 1       12.75          90
# 2       11.41          90
# 3        7.00          51
# 4        1.74          28

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
bad_weather = weather_df.loc[(weather_df["Humidity"]==100),:]
len(bad_weather)
# Out:
# 13

# %%
good_weather = weather_df.loc[(weather_df["Humidity"]<100),:]
clean_city_data = good_weather
clean_city_data
# Out:
#      Unnamed: 0           City Country    Lat     Lng   Temp  Humidity  \
# 0             0         khasan      RU  42.43  130.64  57.02        43
# 1             1    tuktoyaktuk      CA  69.45 -133.04  14.00        85
# 2             2          vaini      TO -21.20 -175.20  73.40        88
# 3             3        mataura      NZ -46.19  168.86  55.99        57
# 4             4           lata      PT  40.16   -8.33  49.28        91
# ..          ...            ...     ...    ...     ...    ...       ...
# 478         478  saint anthony      US  45.02  -93.22  25.75        79
# 479         479   norman wells      CA  65.28 -126.83  28.40        92
# 480         480      tazovskiy      RU  67.47   78.70   4.33        94
# 481         481        vryburg      ZA -26.96   24.73  75.60        38
# 482         482        northam      GB  51.03   -4.22  51.66        85
#
#      Wind Speed  Cloudiness
# 0          0.49           0
# 1         12.75          90
# 2         11.41          90
# 3          7.00          51
# 4          1.74          28
# ..          ...         ...
# 478        4.70          75
# 479       11.41          90
# 480        8.66           5
# 481       12.73          99
# 482       11.99          78
#
# [470 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#All scatter plots - justifies making a function to reduce rework

def plotter(y_val, y_label):
    
    x_label = "Latitude"
    x_val = [clean_city_data["Lat"]]
    title = (f"{y_label} as a Function of {x_label}")
    
    # Build a scatter plot for each data type
    plt.scatter(clean_city_data["Lat"], y_val, marker="o", edgecolors="chocolate",facecolors="orange")
    # Incorporate the other graph properties
    plt.title(title, fontsize = 18)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.grid(False)

    # Show plot
    return plt.show()

y_val = clean_city_data["Temp"]
y_label = "Temperature (F)"
plotter(y_val, y_label)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
y_val = [clean_city_data["Humidity"]]
y_label = "Humidity"

fig_name = (f"Lat_vs_{y_label}.png")

plotter(y_val, y_label)

plt.savefig(fig_name)
#plt.savefig("Humidity_vs_Latitude.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
y_val = [clean_city_data["Cloudiness"]]
y_label = "Cloudiness"
#fig_name = (f"{x_val}_vs_{y_val}")

plotter(y_val, y_label)
plt.savefig("Cloudiness_vs_Latitude.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
y_val = [clean_city_data["Wind Speed"]]
y_label = "Wind Speed"
#fig_name = (f"{x_val}_vs_{y_val}")

plotter(y_val, y_label)
plt.savefig("Wind_Speed_vs_Latitude.png")

# %% [markdown]
# ## Linear Regression

# %%
'''
Making a linear regression function
'''
#Annotation on y-axis needs to shift with each plot; declaring variable outside function
y_ann =-50


#Linear regression function, save rework later
def lr_plotter(y_val, y_label, y_ann, hemi):
    
    #x-label is latitude for all plots; declaring inside function
    x_label = "Latitude"
    title = (f"{y_label} as a Function of {x_label}")

    #Latitude ranges for hemispheres fixed, so use hemisphere for annotation position
    if hemi == "n":
        x_val = northern_df["Lat"]
        x_ann = 0
    else:
        x_val = southern_df["Lat"]
        x_ann = -50

    # Build a scatter plot for each data type
    plt.scatter(x_val, y_val, marker="o", edgecolors="chocolate",facecolors="orange")

    # Incorporate the other graph properties
    plt.title(title, fontsize = 18)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.grid(False)

    #Set up regression
    (slope, intercept, rvalue, pvalue,stderr) = linregress(x_val, y_val)
    regress_values = x_val * slope + intercept
    line_eq = (f"y= " + str(round(slope,2)) + "x + " + str(round(intercept,2)))
    
    #Plot data, regresson equation and annotation
    plt.plot(x_val, regress_values, "r-")
    plt.annotate(line_eq,(x_ann,y_ann),fontsize=12,color="firebrick")
    
    return plt.show()

# %% [markdown]
# ## Hemisphere Data

# %%
#Separate into two dataframes based on latitude

southern_df = clean_city_data.loc[(clean_city_data["Lat"])<=0]
northern_df = clean_city_data.loc[(clean_city_data["Lat"])>=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_val = northern_df["Temp"]
y_label = "Temperature (F)"
hemi = "n"
y_ann=10

lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_val = southern_df["Temp"]
y_label = "Temperature (F)"
hemi = "s"
y_ann=90

lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_val = northern_df["Humidity"]
y_label = "Humidity"
y_ann = 5
hemi = "n"

lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_val = southern_df["Humidity"]
y_label = "Humidity"
y_ann = 20
hemi = "s"


lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_val = northern_df["Cloudiness"]
y_label = "Cloudiness"
y_ann = 30
hemi = "n"



lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_val = southern_df["Cloudiness"]
y_label = "Cloudiness"
y_ann = 10
hemi = "s"



lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_val = northern_df["Wind Speed"]
y_label = "Wind Speed"
hemi = "n"

y_ann = 40
lr_plotter(y_val, y_label, y_ann, hemi)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_val = northern_df["Wind Speed"]
y_label = "Wind Speed"
hemi = "n"

y_ann = 40
lr_plotter(y_val, y_label, y_ann, hemi)

# %%
cities = ["Paris", "London", "Oslo", "Beijing"]

# set up lists to hold reponse info
lat = []
temp = []
country=[]

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])
    country.append(response['sys']['country'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [48.85, 51.51, 59.91, 39.91]
# The temperature information received is: [45.73, 45.59, 44.24, 70.9]

# %%
print(response)
# Out:
# {'coord': {'lon': 116.4, 'lat': 39.91}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 70.5, 'feels_like': 68.23, 'temp_min': 66, 'temp_max': 73.99, 'pressure': 1011, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 201}, 'clouds': {'all': 33}, 'dt': 1603686373, 'sys': {'type': 3, 'id': 2000022, 'country': 'CN', 'sunrise': 1603665385, 'sunset': 1603704003}, 'timezone': 28800, 'id': 1816670, 'name': 'Beijing', 'cod': 200}

# %%
country
# Out:
# ['FR', 'GB', 'NO', 'CN']
